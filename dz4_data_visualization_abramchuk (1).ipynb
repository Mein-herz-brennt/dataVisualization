# %%
import pandas as pd
import csv
import matplotlib.pyplot as plt
import numpy as np

plt.style.use("seaborn-v0_8")
data = pd.read_csv("smoking.csv")
data.head()
# Out:
#        Country  Year  Data.Daily cigarettes  Data.Percentage.Male  \
# 0  Afghanistan  1980                    5.7                  10.4
# 1  Afghanistan  1981                    5.8                  10.5
# 2  Afghanistan  1982                    5.8                  10.5
# 3  Afghanistan  1983                    5.9                  10.5
# 4  Afghanistan  1984                    6.0                  10.6
#
#    Data.Percentage.Female  Data.Percentage.Total  Data.Smokers.Total  \
# 0                    18.4                    2.4              733520
# 1                    18.4                    2.3              720102
# 2                    18.5                    2.3              700415
# 3                    18.6                    2.3              676984
# 4                    18.6                    2.3              653812
#
#    Data.Smokers.Female  Data.Smokers.Male
# 0                81707             651813
# 1                79276             640826
# 2                76061             624355
# 3                72411             604572
# 4                68908             584905

# %%
data_smokers = data[:33]
smokers_female = data_smokers["Data.Smokers.Female"]
smokers_male = data_smokers["Data.Smokers.Male"]
data_time = data_smokers["Year"]
data_total = data_smokers["Data.Smokers.Total"]

# %%
plt.figure()
plt.title('Статистика куріння Афганістан 2010 рік')
a = [data_total[32], smokers_male[32]]
kv = ['всі курці', 'Чоловіки курці']
plt.pie(a, labels = kv)
plt.show()

# %%
fig, ax = plt.subplots(nrows=1, ncols=2)
ax[0].stackplot(data_time, [data_total, smokers_male, smokers_female], colors=['purple', 'yellow', "green"], labels=["male", "female", "total"])
ax[1].plot(data_time, smokers_male)
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fig, ax_outer = plt.subplots()

ax_outer.stackplot(data_time, [data_total, smokers_male, smokers_female], colors=['purple', 'yellow', "green"], labels=["male", "female", "total"])
inner_ax = fig.add_axes([0.6, 0.6, 0.25, 0.25])  # [left, bottom, width, height]
inner_ax.plot(data_time, smokers_male, label='male', color='red')
ax_outer.legend()
inner_ax.legend()
plt.show()
